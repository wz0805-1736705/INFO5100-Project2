# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
dfCount = pd.read_csv('count_by_state.csv')
dfSurvey = pd.read_csv('state-survey-responses-fa21.csv')

# %%
dfCount = dfCount.rename(columns={'province': 'state_short'})
dfCount
# Out:
#    state_short  count
# 0           AK     16
# 1           AL      6
# 2           AR    102
# 3           AZ    330
# 4           CA   1201
# 5           CO    148
# 6           CT     53
# 7           DE     44
# 8           FL    621
# 9           GA    420
# 10          HI     32
# 11          IA    115
# 12          ID     51
# 13          IL    405
# 14          IN    254
# 15          KS     74
# 16          KY    166
# 17          LA    202
# 18          MA    205
# 19          MD    172
# 20          ME     25
# 21          MI    374
# 22          MN    199
# 23          MO    163
# 24          MS     55
# 25          MT     38
# 26          NC    295
# 27          ND     35
# 28          NE     87
# 29          NH     34
# 30          NJ    129
# 31          NM     78
# 32          NV    121
# 33          NY    352
# 34          OH    522
# 35          OK    166
# 36          OR    154
# 37          PA    383
# 38          RI     15
# 39          SC    188
# ...

# %%
dfSurvey
# Out:
#               state_name  total  state_code state_short
# 0                Alabama      5           1          AL
# 1                 Alaska     15           2          AK
# 2                Arizona     28           4          AZ
# 3               Arkansas      3           5          AR
# 4             California    102           6          CA
# 5               Colorado     29           8          CO
# 6            Connecticut     54           9          CT
# 7               Delaware     29          10          DE
# 8   District of Columbia     65          11          DC
# 9                Florida     88          12          FL
# 10               Georgia     26          13          GA
# 11                Hawaii     27          15          HI
# 12                 Idaho      9          16          ID
# 13              Illinois     42          17          IL
# 14               Indiana     20          18          IN
# 15                  Iowa      6          19          IA
# ...

# %%
dfTotal = dfCount.join(dfSurvey.set_index('state_short'), on='state_short')
dfTotal
# Out:
#    state_short  count      state_name  total  state_code
# 0           AK     16          Alaska     15           2
# 1           AL      6         Alabama      5           1
# 2           AR    102        Arkansas      3           5
# 3           AZ    330         Arizona     28           4
# 4           CA   1201      California    102           6
# 5           CO    148        Colorado     29           8
# 6           CT     53     Connecticut     54           9
# 7           DE     44        Delaware     29          10
# 8           FL    621         Florida     88          12
# 9           GA    420         Georgia     26          13
# 10          HI     32          Hawaii     27          15
# 11          IA    115            Iowa      6          19
# 12          ID     51           Idaho      9          16
# 13          IL    405        Illinois     42          17
# 14          IN    254         Indiana     20          18
# ...

# %%
dfTotal = dfTotal[['state_short', 'state_name', 'state_code', 'count']]
dfTotal
# Out:
#    state_short      state_name  state_code  count
# 0           AK          Alaska           2     16
# 1           AL         Alabama           1      6
# 2           AR        Arkansas           5    102
# 3           AZ         Arizona           4    330
# 4           CA      California           6   1201
# 5           CO        Colorado           8    148
# 6           CT     Connecticut           9     53
# 7           DE        Delaware          10     44
# 8           FL         Florida          12    621
# 9           GA         Georgia          13    420
# 10          HI          Hawaii          15     32
# 11          IA            Iowa          19    115
# 12          ID           Idaho          16     51
# 13          IL        Illinois          17    405
# 14          IN         Indiana          18    254
# 15          KS          Kansas          20     74
# 16          KY        Kentucky          21    166
# 17          LA       Louisiana          22    202
# ...

# %%
dfTotal.to_csv('count_with_code.csv', index=False)
