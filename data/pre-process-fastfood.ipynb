# %%
import pandas as pd

# %%
df = pd.read_csv("Fast_Food_Restaurants_US.csv")
df
# Out:
#       Unnamed: 0               address  \
# 0              0      800 N Canal Blvd
# 1              1      800 N Canal Blvd
# 2              2   206 Wears Valley Rd
# 3              3          3652 Parkway
# 4              4  2118 Mt Zion Parkway
# ...          ...                   ...
# 9995        9995     3460 Robinhood Rd
# 9996        9996  3069 Kernersville Rd
# 9997        9997         838 S Main St
# 9998        9998   1702 Glendale Dr SW
# 9999        9999       1405 W Broad St
#
#                                         categories           city country  \
# 0     American Restaurant and Fast Food Restaurant      Thibodaux      US
# 1                            Fast Food Restaurants      Thibodaux      US
# 2                             Fast Food Restaurant   Pigeon Forge      US
# 3                                        Fast Food   Pigeon Forge      US
# 4                             Fast Food Restaurant         Morrow      US
# ...

# %%
df.province.unique()
# Out:
# array(['LA', 'TN', 'GA', 'MI', 'CA', 'NY', 'TX', 'OH', 'SC', 'MS', 'IN',
#        'MA', 'FL', 'MO', 'PA', 'IL', 'CT', 'KY', 'KS', 'IA', 'HI', 'ID',
#        'NC', 'DE', 'AZ', 'WI', 'CO', 'AR', 'SD', 'WV', 'WY', 'VA', 'OR',
#        'MD', 'WA', 'UT', 'NV', 'OK', 'ME', 'ND', 'NH', 'VT', 'NJ', 'NE',
#        'MN', 'MT', 'AL', 'NM', 'AK', 'RI'], dtype=object)

# %%
stateGroup = df.groupby("province").count()
stateGroup
# Out:
#           Unnamed: 0  address  categories  city  country  latitude  longitude  \
# province
# AK                16       16          16    16       16        16         16
# AL                 6        6           6     6        6         6          6
# AR               102      102         102   102      102       102        102
# AZ               330      330         330   330      330       330        330
# CA              1201     1201        1201  1201     1201      1201       1201
# CO               148      148         148   148      148       148        148
# CT                53       53          53    53       53        53         53
# DE                44       44          44    44       44        44         44
# FL               621      621         621   621      621       621        621
# GA               420      420         420   420      420       420        420
# HI                32       32          32    32       32        32         32
# ...

# %%
stateGroup.columns
# Out:
# Index(['Unnamed: 0', 'address', 'categories', 'city', 'country', 'latitude',
#        'longitude', 'name', 'postalCode', 'websites'],
#       dtype='object')

# %%
stateGroup['count'] = stateGroup[stateGroup.columns[0]]

# %%
stateGroup = stateGroup['count']

# %%
stateGroup
# Out:
# province
# AK      16
# AL       6
# AR     102
# AZ     330
# CA    1201
# CO     148
# CT      53
# DE      44
# FL     621
# GA     420
# HI      32
# IA     115
# ID      51
# IL     405
# IN     254
# KS      74
# KY     166
# LA     202
# MA     205
# MD     172
# ME      25
# MI     374
# MN     199
# MO     163
# MS      55
# MT      38
# NC     295
# ND      35
# NE      87
# NH      34
# NJ     129
# NM      78
# NV     121
# NY     352
# OH     522
# OK     166
# OR     154
# PA     383
# RI      15
# SC     188
# SD      42
# TN     302
# TX     811
# UT      63
# VA     253
# VT      15
# WA     196
# WI     189
# WV      70
# WY      29
# Name: count, dtype: int64

# %%
stateGroup.to_csv('count_by_state.csv')
